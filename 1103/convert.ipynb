# %%
# 다중 퍼셉트론 모델 생성 및 학습
import tensorflow as tf

# %%
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
mlp_model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

# %%
mlp_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
mlp_model.fit(x_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2606 - accuracy: 0.9259
# Epoch 2/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1125 - accuracy: 0.9675
# Epoch 3/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0774 - accuracy: 0.9768
# Epoch 4/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0583 - accuracy: 0.9820
# Epoch 5/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0451 - accuracy: 0.9864

# %%
# 케라스 모델 변환
converter = tf.lite.TFLiteConverter.from_keras_model(mlp_model)
tflite_model = converter.convert()
# Out:
# INFO:tensorflow:Assets written to: C:\Users\Public\Documents\ESTsoft\CreatorTemp\tmpto076vyf\assets
# INFO:tensorflow:Assets written to: C:\Users\Public\Documents\ESTsoft\CreatorTemp\tmpto076vyf\assets

# %%
# 케라스 모델 저장
with open('./keras_model.tflite', 'wb') as f:
    f.write(tflite_model)
